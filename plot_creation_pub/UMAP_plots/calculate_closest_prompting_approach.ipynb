# %%
import json
import requests
import logging
import numpy as np
import os
from typing import Dict, List, Optional

# Configure logging: DEBUG for detailed internal state, INFO for high-level outputs.
logging.basicConfig(
    format="%(asctime)s [%(levelname)s] %(message)s",
    level=logging.DEBUG  # Set to INFO for less verbosity if desired
)
logger = logging.getLogger(__name__)

# URL to the local Ollama embedding API endpoint.
EMBED_URL = "http://localhost:11434/api/embed"

def get_embedding_for_drug(drug: str, model: str) -> Optional[np.ndarray]:
    """
    Get the embedding of a drug name by calling the Ollama embedding API.
    
    Args:
        drug (str): The drug name.
        model (str): The model to use for embeddings (e.g. "llama3:8b").
    
    Returns:
        Optional[np.ndarray]: The embedding vector as a NumPy array, or None if request fails.
    """
    payload = {
        "model": model,
        "input": drug
    }
    logger.debug("Requesting embedding for drug '%s' using model '%s'", drug, model)
    try:
        response = requests.post(EMBED_URL, json=payload)
        response.raise_for_status()
        data = response.json()
        # Assuming the embedding is returned in the first (and only) element of "embeddings".
        embedding_list = data["embeddings"][0]
        logger.info("Embedding for drug '%s' received (vector length: %d)", drug, len(embedding_list))
        return np.array(embedding_list)
    except requests.RequestException as err:
        logger.error("Error fetching embedding for drug '%s': %s", drug, str(err))
        return None

def embed_drugs(drug_list: List[str], model: str) -> Dict[str, np.ndarray]:
    """
    For each drug in the provided list, call the Ollama API to get an embedding.
    
    Args:
        drug_list (List[str]): List of drug names.
        model (str): Embedding model to use.
    
    Returns:
        Dict[str, np.ndarray]: Mapping from drug name to its embedding (as a NumPy array).
    """
    embeddings = {}
    for drug in drug_list:
        embedding = get_embedding_for_drug(drug, model)
        if embedding is not None:
            embeddings[drug] = embedding
        else:
            logger.warning("Skipping drug '%s' due to failed embedding.", drug)
    return embeddings

def run_through_all_approaches(approach_files: Dict[str, str], model: str) -> Dict[str, Dict[str, np.ndarray]]:
    """
    Process all approaches by loading the respective JSON files containing drugs,
    generating embeddings for each, and storing the results.
    
    Args:
        approach_files (Dict[str, str]): Mapping of approach names to JSON filenames.
        model (str): Embedding model to use.
    
    Returns:
        Dict[str, Dict[str, np.ndarray]]: Mapping from approach name to a dictionary of (drug -> embedding) pairs.
    """
    all_approach_embeddings = {}
    
    for approach, file_path in approach_files.items():
        if not os.path.exists(file_path):
            logger.error("File %s for approach '%s' not found!", file_path, approach)
            continue
        
        with open(file_path, 'r') as file:
            data = json.load(file)
            # Handle both list and dictionary structures
            if isinstance(data, dict):
                drug_list = list(data.keys())
            else:
                # Assume it's a list of drug names
                drug_list = data
            logger.info("Loaded %d drugs for approach '%s' from %s", len(drug_list), approach, file_path)
        
        embeddings = embed_drugs(drug_list, model)
        all_approach_embeddings[approach] = embeddings
    return all_approach_embeddings

def cosine_similarity(vec1: np.ndarray, vec2: np.ndarray) -> float:
    """
    Calculate the cosine similarity between two embedding vectors.
    
    Args:
        vec1 (np.ndarray): First embedding vector.
        vec2 (np.ndarray): Second embedding vector.
    
    Returns:
        float: Cosine similarity value (range [-1, 1]).
    """
    logger.debug("Calculating cosine similarity.")
    dot_product = np.dot(vec1, vec2)
    norm1 = np.linalg.norm(vec1)
    norm2 = np.linalg.norm(vec2)
    
    if norm1 == 0 or norm2 == 0:
        logger.error("Zero norm encountered.")
        return 0.0
    similarity = dot_product / (norm1 * norm2)
    logger.debug("Cosine similarity: %f", similarity)
    return similarity

def calculate_minimal_distances_to_literature(approach_embeddings: Dict[str, np.ndarray], 
                                           literature_embeddings: Dict[str, np.ndarray]) -> Dict[str, float]:
    """
    For each drug in an approach, compute the minimum cosine distance 
    (1 - cosine similarity) to any drug in the literature comparison set.
    
    Args:
        approach_embeddings (Dict[str, np.ndarray]): Mapping of drug to embedding for one approach.
        literature_embeddings (Dict[str, np.ndarray]): Mapping of drug to embedding for literature comparison.
    
    Returns:
        Dict[str, float]: Mapping from drug name to its minimal distance to any literature drug.
    """
    minimal_distances = {}
    
    for drug, emb in approach_embeddings.items():
        min_distance = float('inf')
        closest_literature_drug = None
        
        for lit_drug, lit_emb in literature_embeddings.items():
            similarity = cosine_similarity(emb, lit_emb)
            distance = 1 - similarity  # convert similarity to distance
            if distance < min_distance:
                min_distance = distance
                closest_literature_drug = lit_drug
        
        minimal_distances[drug] = min_distance
        logger.debug("Drug '%s': minimal cosine distance to literature = %f (closest to '%s')", 
                    drug, min_distance, closest_literature_drug)
    
    return minimal_distances

def compare_approaches_to_literature(all_approach_embeddings: Dict[str, Dict[str, np.ndarray]], 
                                   literature_embeddings: Dict[str, np.ndarray]) -> None:
    """
    For each approach, calculate the minimal distances between its drug embeddings
    and the literature comparison embeddings. Then compare these distances
    to determine which approach is closest to the literature comparison set.
    
    Args:
        all_approach_embeddings (Dict[str, Dict[str, np.ndarray]]): Mapping of approach names to embeddings dict.
        literature_embeddings (Dict[str, np.ndarray]): Embeddings of literature comparison drugs.
    """
    approach_results = {}
    
    for approach, embeddings in all_approach_embeddings.items():
        if approach == "literature":  # Skip the literature set itself
            continue
            
        minimal_distances = calculate_minimal_distances_to_literature(embeddings, literature_embeddings)
        
        # Calculate statistics
        total_distance = sum(minimal_distances.values())
        avg_distance = total_distance / len(minimal_distances)
        min_distance = min(minimal_distances.values())
        max_distance = max(minimal_distances.values())
        
        approach_results[approach] = {
            "total_distance": total_distance,
            "avg_distance": avg_distance,
            "min_distance": min_distance,
            "max_distance": max_distance,
            "num_drugs": len(minimal_distances)
        }
        
        logger.info("Approach '%s' results:", approach)
        logger.info("  Total distance (sum of minimal distances for all drugs in the approach): %f", total_distance)
        logger.info("  Average distance (mean of the minimal distances across all drugs): %f", avg_distance)
        logger.info("  Min distance (smallest minimal distance observed among all drugs.): %f", min_distance)
        logger.info("  Max distance (largest minimal distance observed among all drugs): %f", max_distance)
        logger.info("  Number of drugs (count of drugs successfully embedded and evaluated): %d", len(minimal_distances))
    
    # Find the approach with the smallest total distance
    closest_approach = min(approach_results.items(), key=lambda x: x[1]["total_distance"])
    
    # Print summary results
    print("\nComparison of approaches to literature comparison:")
    print("=" * 50)
    for approach, results in approach_results.items():
        print(f"\n{approach.upper()}:")
        print("  Total distance: {:.4f}".format(results['total_distance']))
        print("    → Sum of minimal distances between each drug in this approach and its closest literature drug")
        print("  Average distance: {:.4f}".format(results['avg_distance']))
        print("    → Mean cosine distance across all drugs, lower values indicate better alignment with literature")
        print("  Min distance: {:.4f}".format(results['min_distance']))
        print("    → Distance of the drug most similar to any literature drug")
        print("  Max distance: {:.4f}".format(results['max_distance']))
        print("    → Distance of the drug least similar to any literature drug")
        print("  Number of drugs: {}".format(results['num_drugs']))
        print("    → Total drugs successfully embedded and compared from this approach")
    
    print(f"\nApproach closest to literature comparison: {closest_approach[0]}")
    print(f"Total distance: {closest_approach[1]['total_distance']:.4f}")

if __name__ == "__main__":
    # Define the JSON file paths for the approaches
    approach_files = {
        "zero_shot": "drug_lists/zero_shot_prompt_top_50_drugs.json",
        "ontological_prompt": "drug_lists/ontological_prompt_top_50_drugs.json",
        "literature": "drug_lists/cummings_eta_al_AD_DR_candidates.json"
    }
    
    # Specify the embedding model to use
    embedding_model = "llama3:8b"
    
    # Run the embedding pipeline for all approaches
    all_embeddings = run_through_all_approaches(approach_files, embedding_model)
    
    # Extract the literature comparison embeddings
    literature_embeddings = all_embeddings.get("literature", {})
    if not literature_embeddings:
        logger.error("No literature embeddings found. Exiting.")
        exit(1)
    
    # Compare approaches to literature comparison
    compare_approaches_to_literature(all_embeddings, literature_embeddings)
# Out:
# 2025-05-27 23:10:06,492 [INFO] Loaded 50 drugs for approach 'zero_shot' from drug_lists/zero_shot_prompt_top_50_drugs.json
# 2025-05-27 23:10:06,493 [DEBUG] Requesting embedding for drug 'Aducanumab' using model 'llama3:8b'
# 2025-05-27 23:10:06,501 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:09,292 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:09,295 [INFO] Embedding for drug 'Aducanumab' received (vector length: 4096)
# 2025-05-27 23:10:09,297 [DEBUG] Requesting embedding for drug 'Lecanemab' using model 'llama3:8b'
# 2025-05-27 23:10:09,300 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:09,426 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:09,428 [INFO] Embedding for drug 'Lecanemab' received (vector length: 4096)
# 2025-05-27 23:10:09,428 [DEBUG] Requesting embedding for drug '6-[3-(4-Morpholinyl)Propyl]-2-(3-Nitrophenyl)-5-Thioxo-5,6,-Dihydro-7h-Thienol[2',3':4,5]Pyrrolo[1,2-C]Imidazol-7-One' using model 'llama3:8b'
# 2025-05-27 23:10:09,430 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:09,759 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:09,760 [INFO] Embedding for drug '6-[3-(4-Morpholinyl)Propyl]-2-(3-Nitrophenyl)-5-Thioxo-5,6,-Dihydro-7h-Thienol[2',3':4,5]Pyrrolo[1,2-C]Imidazol-7-One' received (vector length: 4096)
# 2025-05-27 23:10:09,761 [DEBUG] Requesting embedding for drug 'Memantine' using model 'llama3:8b'
# 2025-05-27 23:10:09,762 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:09,837 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:09,838 [INFO] Embedding for drug 'Memantine' received (vector length: 4096)
# 2025-05-27 23:10:09,839 [DEBUG] Requesting embedding for drug 'Fremanezumab' using model 'llama3:8b'
# 2025-05-27 23:10:09,840 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:09,947 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:09,949 [INFO] Embedding for drug 'Fremanezumab' received (vector length: 4096)
# 2025-05-27 23:10:09,951 [DEBUG] Requesting embedding for drug 'CHF 4227' using model 'llama3:8b'
# 2025-05-27 23:10:09,953 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:10,092 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:10,094 [INFO] Embedding for drug 'CHF 4227' received (vector length: 4096)
# 2025-05-27 23:10:10,095 [DEBUG] Requesting embedding for drug 'CTS-1027' using model 'llama3:8b'
# 2025-05-27 23:10:10,096 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:10,186 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:10,188 [INFO] Embedding for drug 'CTS-1027' received (vector length: 4096)
# 2025-05-27 23:10:10,188 [DEBUG] Requesting embedding for drug 'Gantenerumab' using model 'llama3:8b'
# 2025-05-27 23:10:10,189 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:10,296 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:10,298 [INFO] Embedding for drug 'Gantenerumab' received (vector length: 4096)
# 2025-05-27 23:10:10,300 [DEBUG] Requesting embedding for drug '2-{3-[(2S)-4,4-difluoro-2-(pyrrolidin-1-ylcarbonyl)pyrrolidin-1-yl]-3-oxopropyl}-isoindole-1,3(2H)-dione' using model 'llama3:8b'
# 2025-05-27 23:10:10,303 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:10,548 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:10,553 [INFO] Embedding for drug '2-{3-[(2S)-4,4-difluoro-2-(pyrrolidin-1-ylcarbonyl)pyrrolidin-1-yl]-3-oxopropyl}-isoindole-1,3(2H)-dione' received (vector length: 4096)
# 2025-05-27 23:10:10,555 [DEBUG] Requesting embedding for drug 'Huperzine A' using model 'llama3:8b'
# 2025-05-27 23:10:10,556 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:10,662 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:10,666 [INFO] Embedding for drug 'Huperzine A' received (vector length: 4096)
# 2025-05-27 23:10:10,667 [DEBUG] Requesting embedding for drug 'Galantamine' using model 'llama3:8b'
# 2025-05-27 23:10:10,669 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:10,754 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:10,757 [INFO] Embedding for drug 'Galantamine' received (vector length: 4096)
# 2025-05-27 23:10:10,759 [DEBUG] Requesting embedding for drug 'Tafamidis' using model 'llama3:8b'
# 2025-05-27 23:10:10,761 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:10,850 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:10,853 [INFO] Embedding for drug 'Tafamidis' received (vector length: 4096)
# 2025-05-27 23:10:10,853 [DEBUG] Requesting embedding for drug 'Etheno-NAD' using model 'llama3:8b'
# 2025-05-27 23:10:10,855 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:10,960 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:10,964 [INFO] Embedding for drug 'Etheno-NAD' received (vector length: 4096)
# 2025-05-27 23:10:10,965 [DEBUG] Requesting embedding for drug '2-(2-QUINOLIN-3-YLPYRIDIN-4-YL)-1,5,6,7-TETRAHYDRO-4H-PYRROLO[3,2-C]PYRIDIN-4-ONE' using model 'llama3:8b'
# 2025-05-27 23:10:10,968 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:11,211 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:11,214 [INFO] Embedding for drug '2-(2-QUINOLIN-3-YLPYRIDIN-4-YL)-1,5,6,7-TETRAHYDRO-4H-PYRROLO[3,2-C]PYRIDIN-4-ONE' received (vector length: 4096)
# 2025-05-27 23:10:11,215 [DEBUG] Requesting embedding for drug '7-Hydroxystaurosporine' using model 'llama3:8b'
# 2025-05-27 23:10:11,218 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:11,368 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:11,372 [INFO] Embedding for drug '7-Hydroxystaurosporine' received (vector length: 4096)
# 2025-05-27 23:10:11,373 [DEBUG] Requesting embedding for drug 'MPI-674' using model 'llama3:8b'
# 2025-05-27 23:10:11,377 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:11,463 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:11,466 [INFO] Embedding for drug 'MPI-674' received (vector length: 4096)
# 2025-05-27 23:10:11,468 [DEBUG] Requesting embedding for drug '(1S)-2-[(2S,5R)-2-(AMINOMETHYL)-5-PROP-1-YN-1-YLPYRROLIDIN-1-YL]-1-CYCLOPENTYL-2-OXOETHANAMINE' using model 'llama3:8b'
# 2025-05-27 23:10:11,471 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:11,716 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:11,721 [INFO] Embedding for drug '(1S)-2-[(2S,5R)-2-(AMINOMETHYL)-5-PROP-1-YN-1-YLPYRROLIDIN-1-YL]-1-CYCLOPENTYL-2-OXOETHANAMINE' received (vector length: 4096)
# 2025-05-27 23:10:11,722 [DEBUG] Requesting embedding for drug 'SD-0006' using model 'llama3:8b'
# 2025-05-27 23:10:11,725 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:11,815 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:11,818 [INFO] Embedding for drug 'SD-0006' received (vector length: 4096)
# 2025-05-27 23:10:11,819 [DEBUG] Requesting embedding for drug 'REL-(9R,12S)-9,10,11,12-TETRAHYDRO-9,12-EPOXY-1H-DIINDOLO[1,2,3-FG:3',2',1'-KL]PYRROLO[3,4-I][1,6]BENZODIAZOCINE-1,3(2H)-DIONE' using model 'llama3:8b'
# 2025-05-27 23:10:11,820 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:12,145 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:12,148 [INFO] Embedding for drug 'REL-(9R,12S)-9,10,11,12-TETRAHYDRO-9,12-EPOXY-1H-DIINDOLO[1,2,3-FG:3',2',1'-KL]PYRROLO[3,4-I][1,6]BENZODIAZOCINE-1,3(2H)-DIONE' received (vector length: 4096)
# 2025-05-27 23:10:12,150 [DEBUG] Requesting embedding for drug 'CTS-21166' using model 'llama3:8b'
# 2025-05-27 23:10:12,152 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:12,244 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:12,246 [INFO] Embedding for drug 'CTS-21166' received (vector length: 4096)
# 2025-05-27 23:10:12,247 [DEBUG] Requesting embedding for drug 'Tideglusib' using model 'llama3:8b'
# 2025-05-27 23:10:12,249 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:12,354 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:12,357 [INFO] Embedding for drug 'Tideglusib' received (vector length: 4096)
# 2025-05-27 23:10:12,359 [DEBUG] Requesting embedding for drug 'Kifunensine' using model 'llama3:8b'
# 2025-05-27 23:10:12,362 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:12,465 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:12,468 [INFO] Embedding for drug 'Kifunensine' received (vector length: 4096)
# 2025-05-27 23:10:12,469 [DEBUG] Requesting embedding for drug 'N-{2,2-DIFLUORO-2-[(2R)-PIPERIDIN-2-YL]ETHYL}-2-[2-(1H-1,2,4-TRIAZOL-1-YL)BENZYL][1,3]OXAZOLO[4,5-C]PYRIDIN-4-AMINE' using model 'llama3:8b'
# 2025-05-27 23:10:12,471 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:12,794 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:12,795 [INFO] Embedding for drug 'N-{2,2-DIFLUORO-2-[(2R)-PIPERIDIN-2-YL]ETHYL}-2-[2-(1H-1,2,4-TRIAZOL-1-YL)BENZYL][1,3]OXAZOLO[4,5-C]PYRIDIN-4-AMINE' received (vector length: 4096)
# 2025-05-27 23:10:12,795 [DEBUG] Requesting embedding for drug 'ANX-510' using model 'llama3:8b'
# 2025-05-27 23:10:12,796 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:12,885 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:12,886 [INFO] Embedding for drug 'ANX-510' received (vector length: 4096)
# 2025-05-27 23:10:12,887 [DEBUG] Requesting embedding for drug 'Istradefylline' using model 'llama3:8b'
# 2025-05-27 23:10:12,888 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:13,008 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:13,011 [INFO] Embedding for drug 'Istradefylline' received (vector length: 4096)
# 2025-05-27 23:10:13,012 [DEBUG] Requesting embedding for drug 'Cenicriviroc' using model 'llama3:8b'
# 2025-05-27 23:10:13,015 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:13,121 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:13,124 [INFO] Embedding for drug 'Cenicriviroc' received (vector length: 4096)
# 2025-05-27 23:10:13,125 [DEBUG] Requesting embedding for drug 'Darglitazone' using model 'llama3:8b'
# 2025-05-27 23:10:13,127 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:13,232 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:13,236 [INFO] Embedding for drug 'Darglitazone' received (vector length: 4096)
# 2025-05-27 23:10:13,237 [DEBUG] Requesting embedding for drug 'Genistein' using model 'llama3:8b'
# 2025-05-27 23:10:13,241 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:13,323 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:13,327 [INFO] Embedding for drug 'Genistein' received (vector length: 4096)
# 2025-05-27 23:10:13,328 [DEBUG] Requesting embedding for drug 'CRA_10991' using model 'llama3:8b'
# 2025-05-27 23:10:13,331 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:13,434 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:13,438 [INFO] Embedding for drug 'CRA_10991' received (vector length: 4096)
# 2025-05-27 23:10:13,440 [DEBUG] Requesting embedding for drug '[(2R)-1-[(2S)-2-[[(2S,3S)-1-Chloro-6-(diaminomethylideneamino)-2-hydroxyhexan-3-yl]carbamoyl]pyrrolidin-1-yl]-1-oxo-3-phenylpropan-2-yl]azanium' using model 'llama3:8b'
# 2025-05-27 23:10:13,442 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:13,765 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:13,769 [INFO] Embedding for drug '[(2R)-1-[(2S)-2-[[(2S,3S)-1-Chloro-6-(diaminomethylideneamino)-2-hydroxyhexan-3-yl]carbamoyl]pyrrolidin-1-yl]-1-oxo-3-phenylpropan-2-yl]azanium' received (vector length: 4096)
# 2025-05-27 23:10:13,770 [DEBUG] Requesting embedding for drug 'N-((1R,2S)-2-(5-CHLORO-1H-INDOLE-2-CARBOXAMIDO)CYCLOHEXYL)-5-METHYL-4,5,6,7-TETRAHYDROTHIAZOLO[5,4-C]PYRIDINE-2-CARBOXAMIDE' using model 'llama3:8b'
# 2025-05-27 23:10:13,773 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,097 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,101 [INFO] Embedding for drug 'N-((1R,2S)-2-(5-CHLORO-1H-INDOLE-2-CARBOXAMIDO)CYCLOHEXYL)-5-METHYL-4,5,6,7-TETRAHYDROTHIAZOLO[5,4-C]PYRIDINE-2-CARBOXAMIDE' received (vector length: 4096)
# 2025-05-27 23:10:14,103 [DEBUG] Requesting embedding for drug 'Fisetin' using model 'llama3:8b'
# 2025-05-27 23:10:14,106 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,188 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,191 [INFO] Embedding for drug 'Fisetin' received (vector length: 4096)
# 2025-05-27 23:10:14,193 [DEBUG] Requesting embedding for drug 'Dorsomorphin' using model 'llama3:8b'
# 2025-05-27 23:10:14,196 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,301 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,304 [INFO] Embedding for drug 'Dorsomorphin' received (vector length: 4096)
# 2025-05-27 23:10:14,306 [DEBUG] Requesting embedding for drug 'Bedaquiline' using model 'llama3:8b'
# 2025-05-27 23:10:14,308 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,399 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,402 [INFO] Embedding for drug 'Bedaquiline' received (vector length: 4096)
# 2025-05-27 23:10:14,404 [DEBUG] Requesting embedding for drug 'Rivoglitazone' using model 'llama3:8b'
# 2025-05-27 23:10:14,407 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,530 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,533 [INFO] Embedding for drug 'Rivoglitazone' received (vector length: 4096)
# 2025-05-27 23:10:14,534 [DEBUG] Requesting embedding for drug 'SU9516' using model 'llama3:8b'
# 2025-05-27 23:10:14,536 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,628 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,631 [INFO] Embedding for drug 'SU9516' received (vector length: 4096)
# 2025-05-27 23:10:14,631 [DEBUG] Requesting embedding for drug 'AEG35156' using model 'llama3:8b'
# 2025-05-27 23:10:14,633 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,720 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,722 [INFO] Embedding for drug 'AEG35156' received (vector length: 4096)
# 2025-05-27 23:10:14,723 [DEBUG] Requesting embedding for drug 'Sibrotuzumab' using model 'llama3:8b'
# 2025-05-27 23:10:14,724 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,844 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,845 [INFO] Embedding for drug 'Sibrotuzumab' received (vector length: 4096)
# 2025-05-27 23:10:14,845 [DEBUG] Requesting embedding for drug 'Salinomycin' using model 'llama3:8b'
# 2025-05-27 23:10:14,847 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:14,936 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:14,939 [INFO] Embedding for drug 'Salinomycin' received (vector length: 4096)
# 2025-05-27 23:10:14,940 [DEBUG] Requesting embedding for drug 'Bryostatin 1' using model 'llama3:8b'
# 2025-05-27 23:10:14,941 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:15,061 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:15,064 [INFO] Embedding for drug 'Bryostatin 1' received (vector length: 4096)
# 2025-05-27 23:10:15,065 [DEBUG] Requesting embedding for drug 'PAC-1' using model 'llama3:8b'
# 2025-05-27 23:10:15,066 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:15,155 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:15,157 [INFO] Embedding for drug 'PAC-1' received (vector length: 4096)
# 2025-05-27 23:10:15,158 [DEBUG] Requesting embedding for drug 'BMS-754807' using model 'llama3:8b'
# 2025-05-27 23:10:15,160 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:15,264 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:15,267 [INFO] Embedding for drug 'BMS-754807' received (vector length: 4096)
# 2025-05-27 23:10:15,268 [DEBUG] Requesting embedding for drug 'Rifalazil' using model 'llama3:8b'
# 2025-05-27 23:10:15,270 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:15,373 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:15,376 [INFO] Embedding for drug 'Rifalazil' received (vector length: 4096)
# 2025-05-27 23:10:15,378 [DEBUG] Requesting embedding for drug 'REV131' using model 'llama3:8b'
# 2025-05-27 23:10:15,380 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:15,453 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:15,456 [INFO] Embedding for drug 'REV131' received (vector length: 4096)
# 2025-05-27 23:10:15,457 [DEBUG] Requesting embedding for drug 'Emricasan' using model 'llama3:8b'
# 2025-05-27 23:10:15,459 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:15,541 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:15,543 [INFO] Embedding for drug 'Emricasan' received (vector length: 4096)
# 2025-05-27 23:10:15,544 [DEBUG] Requesting embedding for drug 'GW 597599' using model 'llama3:8b'
# 2025-05-27 23:10:15,545 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:15,633 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:15,636 [INFO] Embedding for drug 'GW 597599' received (vector length: 4096)
# 2025-05-27 23:10:15,636 [DEBUG] Requesting embedding for drug 'GTI 2040' using model 'llama3:8b'
# 2025-05-27 23:10:15,638 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:15,741 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:15,743 [INFO] Embedding for drug 'GTI 2040' received (vector length: 4096)
# 2025-05-27 23:10:15,744 [DEBUG] Requesting embedding for drug '(1S,2R,5S)-5-[3-(TRIFLUOROMETHYL)-5,6-DIHYDRO[1,2,4]TRIAZOLO[4,3-A]PYRAZIN-7(8H)-YL]-2-(2,4,5-TRIFLUOROPHENYL)CYCLOHEXANAMINE' using model 'llama3:8b'
# 2025-05-27 23:10:15,746 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:16,068 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:16,072 [INFO] Embedding for drug '(1S,2R,5S)-5-[3-(TRIFLUOROMETHYL)-5,6-DIHYDRO[1,2,4]TRIAZOLO[4,3-A]PYRAZIN-7(8H)-YL]-2-(2,4,5-TRIFLUOROPHENYL)CYCLOHEXANAMINE' received (vector length: 4096)
# 2025-05-27 23:10:16,073 [DEBUG] Requesting embedding for drug 'CP-744809' using model 'llama3:8b'
# 2025-05-27 23:10:16,076 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:16,165 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:16,168 [INFO] Embedding for drug 'CP-744809' received (vector length: 4096)
# 2025-05-27 23:10:16,170 [DEBUG] Requesting embedding for drug '(5E)-5-[(2,2-DIFLUORO-1,3-BENZODIOXOL-5-YL)METHYLENE]-1,3-THIAZOLIDINE-2,4-DIONE' using model 'llama3:8b'
# 2025-05-27 23:10:16,172 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:16,412 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:16,416 [INFO] Embedding for drug '(5E)-5-[(2,2-DIFLUORO-1,3-BENZODIOXOL-5-YL)METHYLENE]-1,3-THIAZOLIDINE-2,4-DIONE' received (vector length: 4096)
# 2025-05-27 23:10:16,419 [INFO] Loaded 50 drugs for approach 'ontological_prompt' from drug_lists/ontological_prompt_top_50_drugs.json
# 2025-05-27 23:10:16,420 [DEBUG] Requesting embedding for drug 'CTS-21166' using model 'llama3:8b'
# 2025-05-27 23:10:16,421 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:16,512 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:16,514 [INFO] Embedding for drug 'CTS-21166' received (vector length: 4096)
# 2025-05-27 23:10:16,515 [DEBUG] Requesting embedding for drug 'Lecanemab' using model 'llama3:8b'
# 2025-05-27 23:10:16,516 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:16,618 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:16,622 [INFO] Embedding for drug 'Lecanemab' received (vector length: 4096)
# 2025-05-27 23:10:16,623 [DEBUG] Requesting embedding for drug 'Verubecestat' using model 'llama3:8b'
# 2025-05-27 23:10:16,626 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:16,716 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:16,719 [INFO] Embedding for drug 'Verubecestat' received (vector length: 4096)
# 2025-05-27 23:10:16,721 [DEBUG] Requesting embedding for drug 'CAD106' using model 'llama3:8b'
# 2025-05-27 23:10:16,724 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:16,799 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:16,802 [INFO] Embedding for drug 'CAD106' received (vector length: 4096)
# 2025-05-27 23:10:16,804 [DEBUG] Requesting embedding for drug 'NGX267' using model 'llama3:8b'
# 2025-05-27 23:10:16,806 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:16,889 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:16,893 [INFO] Embedding for drug 'NGX267' received (vector length: 4096)
# 2025-05-27 23:10:16,894 [DEBUG] Requesting embedding for drug 'Ripretinib' using model 'llama3:8b'
# 2025-05-27 23:10:16,897 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,032 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,033 [INFO] Embedding for drug 'Ripretinib' received (vector length: 4096)
# 2025-05-27 23:10:17,033 [DEBUG] Requesting embedding for drug 'Brasofensine' using model 'llama3:8b'
# 2025-05-27 23:10:17,034 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,137 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,138 [INFO] Embedding for drug 'Brasofensine' received (vector length: 4096)
# 2025-05-27 23:10:17,139 [DEBUG] Requesting embedding for drug 'CX-717' using model 'llama3:8b'
# 2025-05-27 23:10:17,141 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,221 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,222 [INFO] Embedding for drug 'CX-717' received (vector length: 4096)
# 2025-05-27 23:10:17,224 [DEBUG] Requesting embedding for drug '4-{2-[(7-amino-2-furan-2-yl[1,2,4]triazolo[1,5-a][1,3,5]triazin-5-yl)amino]ethyl}phenol' using model 'llama3:8b'
# 2025-05-27 23:10:17,225 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,466 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,469 [INFO] Embedding for drug '4-{2-[(7-amino-2-furan-2-yl[1,2,4]triazolo[1,5-a][1,3,5]triazin-5-yl)amino]ethyl}phenol' received (vector length: 4096)
# 2025-05-27 23:10:17,471 [DEBUG] Requesting embedding for drug 'D-glucose' using model 'llama3:8b'
# 2025-05-27 23:10:17,473 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,555 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,557 [INFO] Embedding for drug 'D-glucose' received (vector length: 4096)
# 2025-05-27 23:10:17,558 [DEBUG] Requesting embedding for drug 'Aranidipine' using model 'llama3:8b'
# 2025-05-27 23:10:17,560 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,662 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,666 [INFO] Embedding for drug 'Aranidipine' received (vector length: 4096)
# 2025-05-27 23:10:17,667 [DEBUG] Requesting embedding for drug 'JNJ-37822681' using model 'llama3:8b'
# 2025-05-27 23:10:17,670 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,791 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,794 [INFO] Embedding for drug 'JNJ-37822681' received (vector length: 4096)
# 2025-05-27 23:10:17,795 [DEBUG] Requesting embedding for drug 'Umifenovir' using model 'llama3:8b'
# 2025-05-27 23:10:17,797 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,886 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,889 [INFO] Embedding for drug 'Umifenovir' received (vector length: 4096)
# 2025-05-27 23:10:17,890 [DEBUG] Requesting embedding for drug 'Pertuzumab' using model 'llama3:8b'
# 2025-05-27 23:10:17,893 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:17,996 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:17,999 [INFO] Embedding for drug 'Pertuzumab' received (vector length: 4096)
# 2025-05-27 23:10:18,001 [DEBUG] Requesting embedding for drug 'CYT006-AngQb' using model 'llama3:8b'
# 2025-05-27 23:10:18,004 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,125 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,129 [INFO] Embedding for drug 'CYT006-AngQb' received (vector length: 4096)
# 2025-05-27 23:10:18,131 [DEBUG] Requesting embedding for drug 'DPI59' using model 'llama3:8b'
# 2025-05-27 23:10:18,134 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,217 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,221 [INFO] Embedding for drug 'DPI59' received (vector length: 4096)
# 2025-05-27 23:10:18,223 [DEBUG] Requesting embedding for drug 'MK-0354' using model 'llama3:8b'
# 2025-05-27 23:10:18,225 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,314 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,318 [INFO] Embedding for drug 'MK-0354' received (vector length: 4096)
# 2025-05-27 23:10:18,319 [DEBUG] Requesting embedding for drug 'Selenious acid' using model 'llama3:8b'
# 2025-05-27 23:10:18,322 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,413 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,417 [INFO] Embedding for drug 'Selenious acid' received (vector length: 4096)
# 2025-05-27 23:10:18,418 [DEBUG] Requesting embedding for drug 'Indigotindisulfonic acid' using model 'llama3:8b'
# 2025-05-27 23:10:18,421 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,569 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,572 [INFO] Embedding for drug 'Indigotindisulfonic acid' received (vector length: 4096)
# 2025-05-27 23:10:18,573 [DEBUG] Requesting embedding for drug 'Darifenacin' using model 'llama3:8b'
# 2025-05-27 23:10:18,575 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,657 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,658 [INFO] Embedding for drug 'Darifenacin' received (vector length: 4096)
# 2025-05-27 23:10:18,659 [DEBUG] Requesting embedding for drug 'Raclopride' using model 'llama3:8b'
# 2025-05-27 23:10:18,660 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,763 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,766 [INFO] Embedding for drug 'Raclopride' received (vector length: 4096)
# 2025-05-27 23:10:18,767 [DEBUG] Requesting embedding for drug 'Lormetazepam' using model 'llama3:8b'
# 2025-05-27 23:10:18,768 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,872 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,875 [INFO] Embedding for drug 'Lormetazepam' received (vector length: 4096)
# 2025-05-27 23:10:18,876 [DEBUG] Requesting embedding for drug 'Mexazolam' using model 'llama3:8b'
# 2025-05-27 23:10:18,878 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:18,967 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:18,969 [INFO] Embedding for drug 'Mexazolam' received (vector length: 4096)
# 2025-05-27 23:10:18,970 [DEBUG] Requesting embedding for drug 'Imiquimod' using model 'llama3:8b'
# 2025-05-27 23:10:18,971 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,067 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,068 [INFO] Embedding for drug 'Imiquimod' received (vector length: 4096)
# 2025-05-27 23:10:19,069 [DEBUG] Requesting embedding for drug 'Amivantamab' using model 'llama3:8b'
# 2025-05-27 23:10:19,070 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,158 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,162 [INFO] Embedding for drug 'Amivantamab' received (vector length: 4096)
# 2025-05-27 23:10:19,163 [DEBUG] Requesting embedding for drug 'Tisotumab vedotin' using model 'llama3:8b'
# 2025-05-27 23:10:19,166 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,313 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,317 [INFO] Embedding for drug 'Tisotumab vedotin' received (vector length: 4096)
# 2025-05-27 23:10:19,318 [DEBUG] Requesting embedding for drug 'Hyperforin' using model 'llama3:8b'
# 2025-05-27 23:10:19,321 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,403 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,406 [INFO] Embedding for drug 'Hyperforin' received (vector length: 4096)
# 2025-05-27 23:10:19,408 [DEBUG] Requesting embedding for drug 'CYT997' using model 'llama3:8b'
# 2025-05-27 23:10:19,410 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,495 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,498 [INFO] Embedding for drug 'CYT997' received (vector length: 4096)
# 2025-05-27 23:10:19,499 [DEBUG] Requesting embedding for drug 'E-2012' using model 'llama3:8b'
# 2025-05-27 23:10:19,502 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,589 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,592 [INFO] Embedding for drug 'E-2012' received (vector length: 4096)
# 2025-05-27 23:10:19,593 [DEBUG] Requesting embedding for drug 'Rindopepimut' using model 'llama3:8b'
# 2025-05-27 23:10:19,595 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,715 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,718 [INFO] Embedding for drug 'Rindopepimut' received (vector length: 4096)
# 2025-05-27 23:10:19,719 [DEBUG] Requesting embedding for drug 'K-00546' using model 'llama3:8b'
# 2025-05-27 23:10:19,722 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,811 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,814 [INFO] Embedding for drug 'K-00546' received (vector length: 4096)
# 2025-05-27 23:10:19,815 [DEBUG] Requesting embedding for drug 'Aflibercept' using model 'llama3:8b'
# 2025-05-27 23:10:19,818 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:19,940 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:19,943 [INFO] Embedding for drug 'Aflibercept' received (vector length: 4096)
# 2025-05-27 23:10:19,944 [DEBUG] Requesting embedding for drug 'Cryptenamine' using model 'llama3:8b'
# 2025-05-27 23:10:19,947 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,039 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,042 [INFO] Embedding for drug 'Cryptenamine' received (vector length: 4096)
# 2025-05-27 23:10:20,043 [DEBUG] Requesting embedding for drug 'Phenformin' using model 'llama3:8b'
# 2025-05-27 23:10:20,046 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,137 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,140 [INFO] Embedding for drug 'Phenformin' received (vector length: 4096)
# 2025-05-27 23:10:20,141 [DEBUG] Requesting embedding for drug 'Rizatriptan' using model 'llama3:8b'
# 2025-05-27 23:10:20,144 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,247 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,250 [INFO] Embedding for drug 'Rizatriptan' received (vector length: 4096)
# 2025-05-27 23:10:20,251 [DEBUG] Requesting embedding for drug 'Rivanicline' using model 'llama3:8b'
# 2025-05-27 23:10:20,254 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,343 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,346 [INFO] Embedding for drug 'Rivanicline' received (vector length: 4096)
# 2025-05-27 23:10:20,347 [DEBUG] Requesting embedding for drug 'Racepinephrine' using model 'llama3:8b'
# 2025-05-27 23:10:20,349 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,438 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,441 [INFO] Embedding for drug 'Racepinephrine' received (vector length: 4096)
# 2025-05-27 23:10:20,443 [DEBUG] Requesting embedding for drug 'Amifampridine' using model 'llama3:8b'
# 2025-05-27 23:10:20,445 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,547 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,550 [INFO] Embedding for drug 'Amifampridine' received (vector length: 4096)
# 2025-05-27 23:10:20,550 [DEBUG] Requesting embedding for drug 'Tideglusib' using model 'llama3:8b'
# 2025-05-27 23:10:20,552 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,655 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,658 [INFO] Embedding for drug 'Tideglusib' received (vector length: 4096)
# 2025-05-27 23:10:20,659 [DEBUG] Requesting embedding for drug 'Romilkimab' using model 'llama3:8b'
# 2025-05-27 23:10:20,662 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,751 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,753 [INFO] Embedding for drug 'Romilkimab' received (vector length: 4096)
# 2025-05-27 23:10:20,755 [DEBUG] Requesting embedding for drug 'Norgestimate' using model 'llama3:8b'
# 2025-05-27 23:10:20,757 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,839 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,842 [INFO] Embedding for drug 'Norgestimate' received (vector length: 4096)
# 2025-05-27 23:10:20,844 [DEBUG] Requesting embedding for drug 'Topiroxostat' using model 'llama3:8b'
# 2025-05-27 23:10:20,846 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:20,934 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:20,937 [INFO] Embedding for drug 'Topiroxostat' received (vector length: 4096)
# 2025-05-27 23:10:20,938 [DEBUG] Requesting embedding for drug 'Dovitinib' using model 'llama3:8b'
# 2025-05-27 23:10:20,940 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:21,027 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:21,030 [INFO] Embedding for drug 'Dovitinib' received (vector length: 4096)
# 2025-05-27 23:10:21,031 [DEBUG] Requesting embedding for drug 'Propentofylline' using model 'llama3:8b'
# 2025-05-27 23:10:21,032 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:21,135 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:21,139 [INFO] Embedding for drug 'Propentofylline' received (vector length: 4096)
# 2025-05-27 23:10:21,140 [DEBUG] Requesting embedding for drug '3-({[(3S)-3,4-dihydroxybutyl]oxy}amino)-1H,2'H-2,3'-biindol-2'-one' using model 'llama3:8b'
# 2025-05-27 23:10:21,143 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:21,377 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:21,380 [INFO] Embedding for drug '3-({[(3S)-3,4-dihydroxybutyl]oxy}amino)-1H,2'H-2,3'-biindol-2'-one' received (vector length: 4096)
# 2025-05-27 23:10:21,381 [DEBUG] Requesting embedding for drug 'Pirlindole' using model 'llama3:8b'
# 2025-05-27 23:10:21,383 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:21,475 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:21,478 [INFO] Embedding for drug 'Pirlindole' received (vector length: 4096)
# 2025-05-27 23:10:21,480 [DEBUG] Requesting embedding for drug 'Rubidium Rb-82' using model 'llama3:8b'
# 2025-05-27 23:10:21,482 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:21,603 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:21,605 [INFO] Embedding for drug 'Rubidium Rb-82' received (vector length: 4096)
# 2025-05-27 23:10:21,606 [DEBUG] Requesting embedding for drug 'Apalutamide' using model 'llama3:8b'
# 2025-05-27 23:10:21,608 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:21,695 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:21,697 [INFO] Embedding for drug 'Apalutamide' received (vector length: 4096)
# 2025-05-27 23:10:21,698 [DEBUG] Requesting embedding for drug 'RU85493' using model 'llama3:8b'
# 2025-05-27 23:10:21,700 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:21,787 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:21,790 [INFO] Embedding for drug 'RU85493' received (vector length: 4096)
# 2025-05-27 23:10:21,791 [DEBUG] Requesting embedding for drug 'Huperzine A' using model 'llama3:8b'
# 2025-05-27 23:10:21,794 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:21,897 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:21,898 [INFO] Embedding for drug 'Huperzine A' received (vector length: 4096)
# 2025-05-27 23:10:21,899 [INFO] Loaded 22 drugs for approach 'literature' from drug_lists/cummings_eta_al_AD_DR_candidates.json
# 2025-05-27 23:10:21,899 [DEBUG] Requesting embedding for drug 'Brexpiprazole' using model 'llama3:8b'
# 2025-05-27 23:10:21,901 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,001 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,002 [INFO] Embedding for drug 'Brexpiprazole' received (vector length: 4096)
# 2025-05-27 23:10:22,003 [DEBUG] Requesting embedding for drug 'Semaglutide' using model 'llama3:8b'
# 2025-05-27 23:10:22,004 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,095 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,097 [INFO] Embedding for drug 'Semaglutide' received (vector length: 4096)
# 2025-05-27 23:10:22,098 [DEBUG] Requesting embedding for drug 'Rasagiline' using model 'llama3:8b'
# 2025-05-27 23:10:22,099 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,186 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,188 [INFO] Embedding for drug 'Rasagiline' received (vector length: 4096)
# 2025-05-27 23:10:22,189 [DEBUG] Requesting embedding for drug 'Rotigotine' using model 'llama3:8b'
# 2025-05-27 23:10:22,192 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,274 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,277 [INFO] Embedding for drug 'Rotigotine' received (vector length: 4096)
# 2025-05-27 23:10:22,279 [DEBUG] Requesting embedding for drug 'Bumetanide' using model 'llama3:8b'
# 2025-05-27 23:10:22,281 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,383 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,386 [INFO] Embedding for drug 'Bumetanide' received (vector length: 4096)
# 2025-05-27 23:10:22,387 [DEBUG] Requesting embedding for drug 'Sildenafil' using model 'llama3:8b'
# 2025-05-27 23:10:22,390 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,464 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,466 [INFO] Embedding for drug 'Sildenafil' received (vector length: 4096)
# 2025-05-27 23:10:22,467 [DEBUG] Requesting embedding for drug 'Telmisartan' using model 'llama3:8b'
# 2025-05-27 23:10:22,469 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,572 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,575 [INFO] Embedding for drug 'Telmisartan' received (vector length: 4096)
# 2025-05-27 23:10:22,576 [DEBUG] Requesting embedding for drug 'Pantoprazole' using model 'llama3:8b'
# 2025-05-27 23:10:22,579 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,688 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,691 [INFO] Embedding for drug 'Pantoprazole' received (vector length: 4096)
# 2025-05-27 23:10:22,692 [DEBUG] Requesting embedding for drug 'Gabapentin' using model 'llama3:8b'
# 2025-05-27 23:10:22,694 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,776 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,780 [INFO] Embedding for drug 'Gabapentin' received (vector length: 4096)
# 2025-05-27 23:10:22,781 [DEBUG] Requesting embedding for drug 'Atorvastatin' using model 'llama3:8b'
# 2025-05-27 23:10:22,784 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,888 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,890 [INFO] Embedding for drug 'Atorvastatin' received (vector length: 4096)
# 2025-05-27 23:10:22,891 [DEBUG] Requesting embedding for drug 'Fluticasone' using model 'llama3:8b'
# 2025-05-27 23:10:22,894 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:22,982 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:22,985 [INFO] Embedding for drug 'Fluticasone' received (vector length: 4096)
# 2025-05-27 23:10:22,986 [DEBUG] Requesting embedding for drug 'Omeprazole' using model 'llama3:8b'
# 2025-05-27 23:10:22,989 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,076 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,079 [INFO] Embedding for drug 'Omeprazole' received (vector length: 4096)
# 2025-05-27 23:10:23,080 [DEBUG] Requesting embedding for drug 'Mometasone' using model 'llama3:8b'
# 2025-05-27 23:10:23,083 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,170 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,173 [INFO] Embedding for drug 'Mometasone' received (vector length: 4096)
# 2025-05-27 23:10:23,174 [DEBUG] Requesting embedding for drug 'Carvedilol' using model 'llama3:8b'
# 2025-05-27 23:10:23,177 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,265 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,267 [INFO] Embedding for drug 'Carvedilol' received (vector length: 4096)
# 2025-05-27 23:10:23,268 [DEBUG] Requesting embedding for drug 'Riluzole' using model 'llama3:8b'
# 2025-05-27 23:10:23,270 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,359 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,361 [INFO] Embedding for drug 'Riluzole' received (vector length: 4096)
# 2025-05-27 23:10:23,362 [DEBUG] Requesting embedding for drug 'Acamprosate' using model 'llama3:8b'
# 2025-05-27 23:10:23,365 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,466 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,468 [INFO] Embedding for drug 'Acamprosate' received (vector length: 4096)
# 2025-05-27 23:10:23,470 [DEBUG] Requesting embedding for drug 'Baclofen' using model 'llama3:8b'
# 2025-05-27 23:10:23,472 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,560 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,562 [INFO] Embedding for drug 'Baclofen' received (vector length: 4096)
# 2025-05-27 23:10:23,562 [DEBUG] Requesting embedding for drug 'Dextromethorphan' using model 'llama3:8b'
# 2025-05-27 23:10:23,564 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,682 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,684 [INFO] Embedding for drug 'Dextromethorphan' received (vector length: 4096)
# 2025-05-27 23:10:23,685 [DEBUG] Requesting embedding for drug 'Quinidine' using model 'llama3:8b'
# 2025-05-27 23:10:23,687 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,767 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,769 [INFO] Embedding for drug 'Quinidine' received (vector length: 4096)
# 2025-05-27 23:10:23,770 [DEBUG] Requesting embedding for drug 'Pioglitazone' using model 'llama3:8b'
# 2025-05-27 23:10:23,772 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,874 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,876 [INFO] Embedding for drug 'Pioglitazone' received (vector length: 4096)
# 2025-05-27 23:10:23,877 [DEBUG] Requesting embedding for drug 'Ibudilast' using model 'llama3:8b'
# 2025-05-27 23:10:23,880 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:23,972 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:23,975 [INFO] Embedding for drug 'Ibudilast' received (vector length: 4096)
# 2025-05-27 23:10:23,976 [DEBUG] Requesting embedding for drug 'Salsalate' using model 'llama3:8b'
# 2025-05-27 23:10:23,978 [DEBUG] Starting new HTTP connection (1): localhost:11434
# 2025-05-27 23:10:24,066 [DEBUG] http://localhost:11434 "POST /api/embed HTTP/1.1" 200 None
# 2025-05-27 23:10:24,068 [INFO] Embedding for drug 'Salsalate' received (vector length: 4096)
# 2025-05-27 23:10:24,069 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:24,070 [DEBUG] Cosine similarity: 0.713527
# 2025-05-27 23:10:24,070 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:24,071 [DEBUG] Cosine similarity: 0.768279
# 2025-05-27 23:10:24,071 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:24,071 [DEBUG] Cosine similarity: 0.647794
# 2025-05-27 23:10:24,071 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:24,072 [DEBUG] Cosine similarity: 0.553773
# 2025-05-27 23:10:24,072 [DEBUG] Calculating cosine similarity.
# ...
# 2025-05-27 23:10:25,949 [DEBUG] Cosine similarity: 0.775512
# 2025-05-27 23:10:25,950 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,950 [DEBUG] Cosine similarity: 0.632477
# 2025-05-27 23:10:25,950 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,951 [DEBUG] Cosine similarity: 0.771744
# 2025-05-27 23:10:25,951 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,951 [DEBUG] Cosine similarity: 0.735798
# 2025-05-27 23:10:25,951 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,951 [DEBUG] Cosine similarity: 0.843339
# 2025-05-27 23:10:25,952 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,952 [DEBUG] Cosine similarity: 0.680855
# 2025-05-27 23:10:25,952 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,952 [DEBUG] Cosine similarity: 0.745295
# 2025-05-27 23:10:25,952 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,953 [DEBUG] Cosine similarity: 0.740110
# 2025-05-27 23:10:25,953 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,953 [DEBUG] Cosine similarity: 0.727885
# 2025-05-27 23:10:25,954 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,954 [DEBUG] Cosine similarity: 0.731232
# 2025-05-27 23:10:25,954 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,954 [DEBUG] Cosine similarity: 0.578099
# 2025-05-27 23:10:25,955 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,955 [DEBUG] Cosine similarity: 0.705328
# 2025-05-27 23:10:25,955 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,955 [DEBUG] Cosine similarity: 0.636856
# 2025-05-27 23:10:25,955 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,956 [DEBUG] Cosine similarity: 0.778168
# 2025-05-27 23:10:25,956 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,956 [DEBUG] Cosine similarity: 0.863905
# 2025-05-27 23:10:25,956 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,957 [DEBUG] Cosine similarity: 0.746422
# 2025-05-27 23:10:25,957 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,957 [DEBUG] Cosine similarity: 0.743624
# 2025-05-27 23:10:25,957 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,958 [DEBUG] Cosine similarity: 0.685335
# 2025-05-27 23:10:25,958 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,958 [DEBUG] Cosine similarity: 0.769843
# 2025-05-27 23:10:25,958 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,958 [DEBUG] Cosine similarity: 0.767552
# 2025-05-27 23:10:25,959 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,959 [DEBUG] Cosine similarity: 0.755932
# 2025-05-27 23:10:25,959 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,960 [DEBUG] Cosine similarity: 0.846823
# 2025-05-27 23:10:25,960 [DEBUG] Drug 'Pirlindole': minimal cosine distance to literature = 0.136095 (closest to 'Riluzole')
# 2025-05-27 23:10:25,960 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,961 [DEBUG] Cosine similarity: 0.458612
# 2025-05-27 23:10:25,961 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,961 [DEBUG] Cosine similarity: 0.413781
# 2025-05-27 23:10:25,961 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,962 [DEBUG] Cosine similarity: 0.446742
# 2025-05-27 23:10:25,962 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,962 [DEBUG] Cosine similarity: 0.413568
# 2025-05-27 23:10:25,962 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,963 [DEBUG] Cosine similarity: 0.475355
# 2025-05-27 23:10:25,963 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,963 [DEBUG] Cosine similarity: 0.421038
# 2025-05-27 23:10:25,963 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,963 [DEBUG] Cosine similarity: 0.432026
# 2025-05-27 23:10:25,964 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,964 [DEBUG] Cosine similarity: 0.423824
# 2025-05-27 23:10:25,964 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,964 [DEBUG] Cosine similarity: 0.405590
# 2025-05-27 23:10:25,965 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,965 [DEBUG] Cosine similarity: 0.390750
# 2025-05-27 23:10:25,965 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,965 [DEBUG] Cosine similarity: 0.356781
# 2025-05-27 23:10:25,965 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,966 [DEBUG] Cosine similarity: 0.421066
# 2025-05-27 23:10:25,966 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,966 [DEBUG] Cosine similarity: 0.372519
# 2025-05-27 23:10:25,966 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,966 [DEBUG] Cosine similarity: 0.436946
# 2025-05-27 23:10:25,967 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,967 [DEBUG] Cosine similarity: 0.483930
# 2025-05-27 23:10:25,967 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,967 [DEBUG] Cosine similarity: 0.443582
# 2025-05-27 23:10:25,968 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,968 [DEBUG] Cosine similarity: 0.436589
# 2025-05-27 23:10:25,968 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,969 [DEBUG] Cosine similarity: 0.423764
# 2025-05-27 23:10:25,969 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,969 [DEBUG] Cosine similarity: 0.469366
# 2025-05-27 23:10:25,969 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,969 [DEBUG] Cosine similarity: 0.430356
# 2025-05-27 23:10:25,970 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,970 [DEBUG] Cosine similarity: 0.441615
# 2025-05-27 23:10:25,970 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,971 [DEBUG] Cosine similarity: 0.470937
# 2025-05-27 23:10:25,971 [DEBUG] Drug 'Rubidium Rb-82': minimal cosine distance to literature = 0.516070 (closest to 'Riluzole')
# 2025-05-27 23:10:25,971 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,971 [DEBUG] Cosine similarity: 0.870429
# 2025-05-27 23:10:25,971 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,972 [DEBUG] Cosine similarity: 0.823412
# 2025-05-27 23:10:25,972 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,972 [DEBUG] Cosine similarity: 0.779204
# 2025-05-27 23:10:25,972 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,972 [DEBUG] Cosine similarity: 0.697033
# 2025-05-27 23:10:25,973 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,973 [DEBUG] Cosine similarity: 0.780684
# 2025-05-27 23:10:25,973 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,973 [DEBUG] Cosine similarity: 0.654314
# 2025-05-27 23:10:25,974 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,974 [DEBUG] Cosine similarity: 0.787186
# 2025-05-27 23:10:25,974 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,975 [DEBUG] Cosine similarity: 0.711967
# 2025-05-27 23:10:25,975 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,975 [DEBUG] Cosine similarity: 0.739016
# 2025-05-27 23:10:25,975 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,976 [DEBUG] Cosine similarity: 0.761189
# 2025-05-27 23:10:25,976 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,976 [DEBUG] Cosine similarity: 0.570461
# 2025-05-27 23:10:25,977 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,977 [DEBUG] Cosine similarity: 0.718623
# 2025-05-27 23:10:25,977 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,977 [DEBUG] Cosine similarity: 0.589821
# 2025-05-27 23:10:25,977 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,978 [DEBUG] Cosine similarity: 0.786018
# 2025-05-27 23:10:25,978 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,978 [DEBUG] Cosine similarity: 0.823769
# 2025-05-27 23:10:25,978 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,979 [DEBUG] Cosine similarity: 0.704135
# 2025-05-27 23:10:25,979 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,979 [DEBUG] Cosine similarity: 0.698700
# 2025-05-27 23:10:25,980 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,980 [DEBUG] Cosine similarity: 0.628751
# 2025-05-27 23:10:25,980 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,980 [DEBUG] Cosine similarity: 0.642814
# 2025-05-27 23:10:25,980 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,981 [DEBUG] Cosine similarity: 0.801871
# 2025-05-27 23:10:25,981 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,981 [DEBUG] Cosine similarity: 0.850281
# 2025-05-27 23:10:25,981 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,982 [DEBUG] Cosine similarity: 0.655217
# 2025-05-27 23:10:25,982 [DEBUG] Drug 'Apalutamide': minimal cosine distance to literature = 0.129571 (closest to 'Brexpiprazole')
# 2025-05-27 23:10:25,982 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,982 [DEBUG] Cosine similarity: 0.244803
# 2025-05-27 23:10:25,982 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,983 [DEBUG] Cosine similarity: 0.200027
# 2025-05-27 23:10:25,983 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,983 [DEBUG] Cosine similarity: 0.236405
# 2025-05-27 23:10:25,983 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,984 [DEBUG] Cosine similarity: 0.251743
# 2025-05-27 23:10:25,984 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,984 [DEBUG] Cosine similarity: 0.245810
# 2025-05-27 23:10:25,984 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,984 [DEBUG] Cosine similarity: 0.178930
# 2025-05-27 23:10:25,985 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,985 [DEBUG] Cosine similarity: 0.223184
# 2025-05-27 23:10:25,985 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,986 [DEBUG] Cosine similarity: 0.216205
# 2025-05-27 23:10:25,986 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,986 [DEBUG] Cosine similarity: 0.198898
# 2025-05-27 23:10:25,986 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,990 [DEBUG] Cosine similarity: 0.174121
# 2025-05-27 23:10:25,991 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,992 [DEBUG] Cosine similarity: 0.147156
# 2025-05-27 23:10:25,992 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,993 [DEBUG] Cosine similarity: 0.198414
# 2025-05-27 23:10:25,993 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,994 [DEBUG] Cosine similarity: 0.164531
# 2025-05-27 23:10:25,994 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,994 [DEBUG] Cosine similarity: 0.204154
# 2025-05-27 23:10:25,994 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,995 [DEBUG] Cosine similarity: 0.254362
# 2025-05-27 23:10:25,995 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,995 [DEBUG] Cosine similarity: 0.238307
# 2025-05-27 23:10:25,995 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,995 [DEBUG] Cosine similarity: 0.184100
# 2025-05-27 23:10:25,996 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,996 [DEBUG] Cosine similarity: 0.188592
# 2025-05-27 23:10:25,996 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,997 [DEBUG] Cosine similarity: 0.236006
# 2025-05-27 23:10:25,997 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,997 [DEBUG] Cosine similarity: 0.214582
# 2025-05-27 23:10:25,997 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,998 [DEBUG] Cosine similarity: 0.250666
# 2025-05-27 23:10:25,998 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,998 [DEBUG] Cosine similarity: 0.391660
# 2025-05-27 23:10:25,998 [DEBUG] Drug 'RU85493': minimal cosine distance to literature = 0.608340 (closest to 'Salsalate')
# 2025-05-27 23:10:25,998 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,999 [DEBUG] Cosine similarity: 0.650522
# 2025-05-27 23:10:25,999 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:25,999 [DEBUG] Cosine similarity: 0.586042
# 2025-05-27 23:10:25,999 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,000 [DEBUG] Cosine similarity: 0.663387
# 2025-05-27 23:10:26,000 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,000 [DEBUG] Cosine similarity: 0.621519
# 2025-05-27 23:10:26,000 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,001 [DEBUG] Cosine similarity: 0.733033
# 2025-05-27 23:10:26,001 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,001 [DEBUG] Cosine similarity: 0.625709
# 2025-05-27 23:10:26,001 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,002 [DEBUG] Cosine similarity: 0.676771
# 2025-05-27 23:10:26,002 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,002 [DEBUG] Cosine similarity: 0.654957
# 2025-05-27 23:10:26,058 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,059 [DEBUG] Cosine similarity: 0.653306
# 2025-05-27 23:10:26,059 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,059 [DEBUG] Cosine similarity: 0.656399
# 2025-05-27 23:10:26,060 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,060 [DEBUG] Cosine similarity: 0.472140
# 2025-05-27 23:10:26,060 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,061 [DEBUG] Cosine similarity: 0.652541
# 2025-05-27 23:10:26,061 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,061 [DEBUG] Cosine similarity: 0.536107
# 2025-05-27 23:10:26,061 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,061 [DEBUG] Cosine similarity: 0.679318
# 2025-05-27 23:10:26,062 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,062 [DEBUG] Cosine similarity: 0.741419
# 2025-05-27 23:10:26,062 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,063 [DEBUG] Cosine similarity: 0.626279
# 2025-05-27 23:10:26,063 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,063 [DEBUG] Cosine similarity: 0.632262
# 2025-05-27 23:10:26,063 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,064 [DEBUG] Cosine similarity: 0.586377
# 2025-05-27 23:10:26,064 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,064 [DEBUG] Cosine similarity: 0.620559
# 2025-05-27 23:10:26,065 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,065 [DEBUG] Cosine similarity: 0.678007
# 2025-05-27 23:10:26,065 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,066 [DEBUG] Cosine similarity: 0.665849
# 2025-05-27 23:10:26,066 [DEBUG] Calculating cosine similarity.
# 2025-05-27 23:10:26,066 [DEBUG] Cosine similarity: 0.742022
# 2025-05-27 23:10:26,066 [DEBUG] Drug 'Huperzine A': minimal cosine distance to literature = 0.257978 (closest to 'Salsalate')
# 2025-05-27 23:10:26,067 [INFO] Approach 'ontological_prompt' results:
# 2025-05-27 23:10:26,067 [INFO]   Total distance (sum of minimal distances for all drugs in the approach): 14.772076
# 2025-05-27 23:10:26,067 [INFO]   Average distance (mean of the minimal distances across all drugs): 0.295442
# 2025-05-27 23:10:26,067 [INFO]   Min distance (smallest minimal distance observed among all drugs.): 0.103889
# 2025-05-27 23:10:26,068 [INFO]   Max distance (largest minimal distance observed among all drugs): 0.692787
# 2025-05-27 23:10:26,068 [INFO]   Number of drugs (count of drugs successfully embedded and evaluated): 50
# Comparison of approaches to literature comparison:
# ==================================================
#
# ZERO_SHOT:
#   Total distance: 18.8076
#     → Sum of minimal distances between each drug in this approach and its closest literature drug
#   Average distance: 0.3762
#     → Mean cosine distance across all drugs, lower values indicate better alignment with literature
#   Min distance: 0.1105
#     → Distance of the drug most similar to any literature drug
#   Max distance: 0.6926
#     → Distance of the drug least similar to any literature drug
#   Number of drugs: 50
#     → Total drugs successfully embedded and compared from this approach
#
# ONTOLOGICAL_PROMPT:
#   Total distance: 14.7721
#     → Sum of minimal distances between each drug in this approach and its closest literature drug
#   Average distance: 0.2954
#     → Mean cosine distance across all drugs, lower values indicate better alignment with literature
#   Min distance: 0.1039
#     → Distance of the drug most similar to any literature drug
#   Max distance: 0.6928
#     → Distance of the drug least similar to any literature drug
#   Number of drugs: 50
#     → Total drugs successfully embedded and compared from this approach
#
# Approach closest to literature comparison: ontological_prompt
# Total distance: 14.7721
